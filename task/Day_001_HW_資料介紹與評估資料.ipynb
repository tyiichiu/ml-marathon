# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y_true, y_pred):
    """
    請完成這個 Function 後往下執行
    """
    squared_errors = [(true - pred) ** 2 for true, pred in zip(y_true, y_pred)]
    mse = sum(squared_errors) / len(y_true)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 217.161
# The Mean absolute error is 11.501

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
#     ```
#     Stress Detection from Social Media Articles
#     https://www.kaggle.com/datasets/mexwell/stress-detection-from-social-media-articles/data
#     從社交媒體文章可以間接地觀察到發文者的身心狀況，發現潛在需要幫助的人
#     ```
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#     ```
#     作者是 Aryan Rastogi, Liu Qian 和 Erik Cambria
#     他們收集自 Reddit 和 Twitter 社群媒體文章
#     ```
#
# 3. 蒐集而來的資料型態為何
#
#     ```
#     包含有字串與整數型態
#     ```
#
# 4. 這組資料想解決的問題如何評估
#
#     ```
#     目的解決文章的二元分類，評估指標可以使用 Accuracy 進行衡量
#     假設資料集分佈是 skewed distribution，評估指標改用 F1-Score 會更為洽當
#     ```
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#     ```
#     假設以提升業績為前提，需要準確地預測顧客熱點，以及提供駕駛適當的車輛行駛路線減少空車率
#     ```
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#     ```
#     政府開放資料集: 縣市圖籍資料、展覽活動資料
#     網路爬蟲: 社群媒體上熱烈討論的活動
#     ```
#
# 3. 蒐集而來的資料型態為何
#
#     ```
#     包括字串、整數、浮點數型態
#     ```
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#     ```
#     將過往業績數據進行拆分，80% 作為訓練，20% 作為驗證
#     可以使用平均絕對誤差(MAE)進行衡量
#     ```
